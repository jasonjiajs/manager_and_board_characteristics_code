# %%
import pandas as pd, numpy as np
from pathlib import Path
import os, sys, glob
from itertools import compress

# %%
# Import list_of_columns.xlsx for boardex
listofcols_path = Path(r"C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\documentation\list_of_variables\List of Variables for Boardex and Execucomp 230322.xlsx")
df = pd.read_excel(listofcols_path, sheet_name=['ExecuComp', 'Boardex - Europe'])
# Out:
# C:\Users\jasonjia\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)

# %%
# Get df for execucomp (not needed here)
# df_execucomp = df['ExecuComp']
# df_execucomp
# Out:
#      Include in Dataset  S/N     Table Variable Name    Type  \
# 0                   NaN    1   ANNCOMP       ADDRESS  string
# 1                   NaN    2   ANNCOMP          CITY  string
# 2                   NaN    3   ANNCOMP        CONAME  string
# 3                   NaN    4   ANNCOMP         CUSIP  string
# 4                   NaN    5   ANNCOMP      EXCHANGE  string
# ..                  ...  ...       ...           ...     ...
# 588                 NaN  589  STGRTTAB      PCDVALUE  string
# 589                 NaN  590  STGRTTAB     PCTTOTOPT  double
# 590                 NaN  591  STGRTTAB        RELOAD  double
# 591                 NaN  592  STGRTTAB         VALUE  double
# 592                 NaN  593  STGRTTAB          YEAR  double
#
#                                            Description  Count (Var Name)  \
# 0                             Street Address (ADDRESS)                11
# 1                                   CITY - City (CITY)                11
# 2                                Company Name (CONAME)                12
# 3                                        CUSIP (CUSIP)                12
# 4                                  Exchange (EXCHANGE)                11
# ..                                                 ...               ...
# 588    PCDVALUE -- Company Valuation Method (PCDVALUE)                 1
# 589  PCTTOTOPT -- Pct of Total Options Grantd to Em...                 1
# 590                     RELOAD -- Reload Flag (RELOAD)                 1
# 591                   VALUE -- Value (Company) (VALUE)                 1
# 592                         YEAR -- Fiscal Year (YEAR)                10
#
#      X-th Occurrence (Var Name)  Count (Desc)  X-th Occurrence (Desc)
# 0                             1            10                       1
# 1                             1             4                       1
# 2                             1            12                       1
# 3                             1             4                       1
# 4                             1             5                       1
# ..                          ...           ...                     ...
# 588                           1             1                       1
# 589                           1             1                       1
# 590                           1             1                       1
# 591                           1             1                       1
# 592                          10             6                       6
#
# [593 rows x 10 columns]

# %%
# Get df for boardex and filter to keep the relevant columns
df_boardex = df['Boardex - Europe']
df_boardex = df_boardex[['Include in Dataset', 'Excel Workbook', 'Excel Workbook (SMDEs)', 'Sheet', 'Variable Name']]

# %%
# Filter to keep only variables that you want to keep 
df_boardex = df_boardex[df_boardex['Include in Dataset'] == 1]
df_boardex = df_boardex.reset_index(drop=True)
df_boardex
# Out:
#     Include in Dataset                                     Excel Workbook  \
# 0                  1.0                             Europe - Board Summary
# 1                  1.0                             Europe - Board Summary
# 2                  1.0                             Europe - Board Summary
# 3                  1.0                             Europe - Board Summary
# 4                  1.0                             Europe - Board Summary
# 5                  1.0                             Europe - Board Summary
# 6                  1.0                             Europe - Board Summary
# 7                  1.0                             Europe - Board Summary
# 8                  1.0                             Europe - Board Summary
# 9                  1.0                             Europe - Board Summary
# 10                 1.0                             Europe - Board Summary
# 11                 1.0                             Europe - Board Summary
# 12                 1.0                             Europe - Board Summary
# 13                 1.0                             Europe - Board Summary
# 14                 1.0                             Europe - Board Summary
# 15                 1.0                             Europe - Board Summary
# 16                 1.0                             Europe - Board Summary
# 17                 1.0                             Europe - Board Summary
# 18                 1.0                             Europe - Board Summary
# 19                 1.0                             Europe - Board Summary
# 20                 1.0                             Europe - Board Summary
# 21                 1.0                             Europe - Board Summary
# 22                 1.0                           Europe - Company Details
# 23                 1.0                           Europe - Company Details
# 24                 1.0        Europe - Director Profile - Characteristics
# 25                 1.0        Europe - Director Profile - Characteristics
# 26                 1.0  Europe - Director Profile - Education & Achiev...
# 27                 1.0  Europe - Director Profile - Education & Achiev...
# 28                 1.0  Europe - Director Profile - Education & Achiev...
# 29                 1.0  Europe - Director Profile - Education & Achiev...
# 30                 1.0  Europe - Director Profile - Education & Achiev...
# 31                 1.0  Europe - Director Profile - Education & Achiev...
# 32                 1.0  Europe - Director Profile - Education & Achiev...
# 33                 1.0  Europe - Director Profile - Education & Achiev...
# 34                 1.0  Europe - Director Profile - Education & Achiev...
# 35                 1.0  Europe - Director Profile - Education & Achiev...
# 36                 1.0  Europe - Director Profile - Education & Achiev...
# 37                 1.0  Europe - Director Profile - Education & Achiev...
# 38                 1.0  Europe - Director Profile - Education & Achiev...
# 39                 1.0  Europe - Director Profile - Education & Achiev...
# 40                 1.0  Europe - Director Profile - Education & Achiev...
#
#                                Excel Workbook (SMDEs)            Sheet  \
# 0                          Europe - SMDEs Org Summary    Board Summary
# 1                          Europe - SMDEs Org Summary    Board Summary
# 2                          Europe - SMDEs Org Summary    Board Summary
# 3                          Europe - SMDEs Org Summary    Board Summary
# 4                          Europe - SMDEs Org Summary    Board Summary
# 5                          Europe - SMDEs Org Summary    Board Summary
# 6                          Europe - SMDEs Org Summary    Board Summary
# 7                          Europe - SMDEs Org Summary    Board Summary
# 8                          Europe - SMDEs Org Summary    Board Summary
# 9                          Europe - SMDEs Org Summary    Board Summary
# 10                         Europe - SMDEs Org Summary    Board Summary
# 11                         Europe - SMDEs Org Summary    Board Summary
# 12                         Europe - SMDEs Org Summary    Board Summary
# 13                         Europe - SMDEs Org Summary    Board Summary
# 14                         Europe - SMDEs Org Summary    Board Summary
# 15                         Europe - SMDEs Org Summary    Board Summary
# 16                         Europe - SMDEs Org Summary    Board Summary
# 17                         Europe - SMDEs Org Summary    Board Summary
# 18                         Europe - SMDEs Org Summary    Board Summary
# 19                                                NaN    Board Summary
# 20                         Europe - SMDEs Org Summary    Board Summary
# 21                         Europe - SMDEs Org Summary    Board Summary
# 22                                                NaN  Company Details
# 23                                                NaN  Company Details
# 24           Europe - SMDEs Profile - Characteristics   Charcteristics
# 25           Europe - SMDEs Profile - Characteristics   Charcteristics
# 26  Europe - SMDEs Profile - Education & Achievements        Education
# 27  Europe - SMDEs Profile - Education & Achievements        Education
# 28  Europe - SMDEs Profile - Education & Achievements        Education
# 29  Europe - SMDEs Profile - Education & Achievements        Education
# 30  Europe - SMDEs Profile - Education & Achievements        Education
# 31  Europe - SMDEs Profile - Education & Achievements        Education
# 32  Europe - SMDEs Profile - Education & Achievements        Education
# 33  Europe - SMDEs Profile - Education & Achievements        Education
# 34  Europe - SMDEs Profile - Education & Achievements     Achievements
# 35  Europe - SMDEs Profile - Education & Achievements     Achievements
# 36  Europe - SMDEs Profile - Education & Achievements     Achievements
# 37  Europe - SMDEs Profile - Education & Achievements     Achievements
# 38  Europe - SMDEs Profile - Education & Achievements     Achievements
# 39  Europe - SMDEs Profile - Education & Achievements     Achievements
# 40  Europe - SMDEs Profile - Education & Achievements     Achievements
#
#                                         Variable Name
# 0                                  Annual Report Year
# 1                                          CompanyID*
# 2                                        Company Name
# 3                                                ISIN
# 4                                              Sector
# 5                            Director Type (ED or SD)
# 6                                         DirectorID*
# 7                                     Individual Name
# 8        Characteristics of Roles\t - Individual Role
# 9           Characteristics of Roles\t - Time in Role
# 10         Characteristics of Roles\t - Time on Board
# 11       Characteristics of Roles\t - Time in Company
# 12  Director Experience - Total Number of Quoted B...
# 13                    Director Experience - Age (Yrs)
# 14                       Director Experience - Gender
# 15              Director Experience - Nationality Mix
# 16                     Ratios - Bonus/ (Bonus&Salary)
# 17                      Ratios - Equity Linked/ Total
# 18                        Ratios - Performance/ Total
# 19  Director Count Totals - Total Directors on the...
# 20                Annual Direct Compensation - Salary
# 21                 Total - Total Annual Compensation
# 22                                         CompanyID*
# 23                                            Bankers
# 24                                        DirectorID*
# 25                                                DOB
# 26                                        DirectorID*
# 27                                      Director Name
# 28                                     InstitutionID*
# 29                                   Institution Name
# 30                                       Company Type
# 31                                      Qualification
# 32                          Qualification Description
# 33                                 Qualification Date
# 34                                            Country
# 35                                        DirectorID*
# 36                                      Director Name
# 37                                    OrganisationID*
# 38                                   OrganisationName
# 39                                   Achievement Date
# 40                                  Award/Achievement

# %%
# Substitute 'Europe - ' with '' in string_to_replace at all occurances
df_boardex['Excel Workbook'] = df_boardex['Excel Workbook'].str.replace('Europe - ','')
df_boardex['Excel Workbook (SMDEs)'] = df_boardex['Excel Workbook (SMDEs)'].str.replace('Europe - ','')

# Remove the "[...] - " part from variable names, because it's the header and not the actual variable name
df_boardex['Variable Name'] = df_boardex['Variable Name'].str.replace('Characteristics of Roles\t - ','')
df_boardex['Variable Name'] = df_boardex['Variable Name'].str.replace('Director Experience - ','')
df_boardex['Variable Name'] = df_boardex['Variable Name'].str.replace('Ratios - ','')
df_boardex['Variable Name'] = df_boardex['Variable Name'].str.replace('Director Count Totals - ','')
df_boardex['Variable Name'] = df_boardex['Variable Name'].str.replace('Ratios - ','')
df_boardex['Variable Name'] = df_boardex['Variable Name'].str.replace('Annual Direct Compensation - ','')
df_boardex['Variable Name'] = df_boardex['Variable Name'].str.replace('Total - ','')

# Rename 'Director Type (ED or SD)' to 'Director Type', because different excel files name it differently, 
# e.g. 'Director Type (ED or SD)' or Director Type (ED , SD or SM)''
df_boardex['Variable Name'] = df_boardex['Variable Name'].str.replace('Director Type (ED or SD)','Director Type')

df_boardex
# Out:
#     Include in Dataset                               Excel Workbook  \
# 0                  1.0                                Board Summary
# 1                  1.0                                Board Summary
# 2                  1.0                                Board Summary
# 3                  1.0                                Board Summary
# 4                  1.0                                Board Summary
# 5                  1.0                                Board Summary
# 6                  1.0                                Board Summary
# 7                  1.0                                Board Summary
# 8                  1.0                                Board Summary
# 9                  1.0                                Board Summary
# 10                 1.0                                Board Summary
# 11                 1.0                                Board Summary
# 12                 1.0                                Board Summary
# 13                 1.0                                Board Summary
# 14                 1.0                                Board Summary
# 15                 1.0                                Board Summary
# 16                 1.0                                Board Summary
# 17                 1.0                                Board Summary
# 18                 1.0                                Board Summary
# 19                 1.0                                Board Summary
# 20                 1.0                                Board Summary
# 21                 1.0                                Board Summary
# 22                 1.0                              Company Details
# 23                 1.0                              Company Details
# 24                 1.0           Director Profile - Characteristics
# 25                 1.0           Director Profile - Characteristics
# 26                 1.0  Director Profile - Education & Achievements
# 27                 1.0  Director Profile - Education & Achievements
# 28                 1.0  Director Profile - Education & Achievements
# 29                 1.0  Director Profile - Education & Achievements
# 30                 1.0  Director Profile - Education & Achievements
# 31                 1.0  Director Profile - Education & Achievements
# 32                 1.0  Director Profile - Education & Achievements
# 33                 1.0  Director Profile - Education & Achievements
# 34                 1.0  Director Profile - Education & Achievements
# 35                 1.0  Director Profile - Education & Achievements
# 36                 1.0  Director Profile - Education & Achievements
# 37                 1.0  Director Profile - Education & Achievements
# 38                 1.0  Director Profile - Education & Achievements
# 39                 1.0  Director Profile - Education & Achievements
# 40                 1.0  Director Profile - Education & Achievements
#
#                       Excel Workbook (SMDEs)            Sheet  \
# 0                          SMDEs Org Summary    Board Summary
# 1                          SMDEs Org Summary    Board Summary
# 2                          SMDEs Org Summary    Board Summary
# 3                          SMDEs Org Summary    Board Summary
# 4                          SMDEs Org Summary    Board Summary
# 5                          SMDEs Org Summary    Board Summary
# 6                          SMDEs Org Summary    Board Summary
# 7                          SMDEs Org Summary    Board Summary
# 8                          SMDEs Org Summary    Board Summary
# 9                          SMDEs Org Summary    Board Summary
# 10                         SMDEs Org Summary    Board Summary
# 11                         SMDEs Org Summary    Board Summary
# 12                         SMDEs Org Summary    Board Summary
# 13                         SMDEs Org Summary    Board Summary
# 14                         SMDEs Org Summary    Board Summary
# 15                         SMDEs Org Summary    Board Summary
# 16                         SMDEs Org Summary    Board Summary
# 17                         SMDEs Org Summary    Board Summary
# 18                         SMDEs Org Summary    Board Summary
# 19                                       NaN    Board Summary
# 20                         SMDEs Org Summary    Board Summary
# 21                         SMDEs Org Summary    Board Summary
# 22                                       NaN  Company Details
# 23                                       NaN  Company Details
# 24           SMDEs Profile - Characteristics   Charcteristics
# 25           SMDEs Profile - Characteristics   Charcteristics
# 26  SMDEs Profile - Education & Achievements        Education
# 27  SMDEs Profile - Education & Achievements        Education
# 28  SMDEs Profile - Education & Achievements        Education
# 29  SMDEs Profile - Education & Achievements        Education
# 30  SMDEs Profile - Education & Achievements        Education
# 31  SMDEs Profile - Education & Achievements        Education
# 32  SMDEs Profile - Education & Achievements        Education
# 33  SMDEs Profile - Education & Achievements        Education
# 34  SMDEs Profile - Education & Achievements     Achievements
# 35  SMDEs Profile - Education & Achievements     Achievements
# 36  SMDEs Profile - Education & Achievements     Achievements
# 37  SMDEs Profile - Education & Achievements     Achievements
# 38  SMDEs Profile - Education & Achievements     Achievements
# 39  SMDEs Profile - Education & Achievements     Achievements
# 40  SMDEs Profile - Education & Achievements     Achievements
#
#                             Variable Name
# 0                      Annual Report Year
# 1                              CompanyID*
# 2                            Company Name
# 3                                    ISIN
# 4                                  Sector
# 5                Director Type (ED or SD)
# 6                             DirectorID*
# 7                         Individual Name
# 8                         Individual Role
# 9                            Time in Role
# 10                          Time on Board
# 11                        Time in Company
# 12  Total Number of Quoted Boards to Date
# 13                              Age (Yrs)
# 14                                 Gender
# 15                        Nationality Mix
# 16                  Bonus/ (Bonus&Salary)
# 17                   Equity Linked/ Total
# 18                     Performance/ Total
# 19           Total Directors on the Board
# 20                                 Salary
# 21             Total Annual Compensation
# 22                             CompanyID*
# 23                                Bankers
# 24                            DirectorID*
# 25                                    DOB
# 26                            DirectorID*
# 27                          Director Name
# 28                         InstitutionID*
# 29                       Institution Name
# 30                           Company Type
# 31                          Qualification
# 32              Qualification Description
# 33                     Qualification Date
# 34                                Country
# 35                            DirectorID*
# 36                          Director Name
# 37                        OrganisationID*
# 38                       OrganisationName
# 39                       Achievement Date
# 40                      Award/Achievement

# %%
# Get unique list of excel workbook names
unique_workbook_names = df_boardex['Excel Workbook'].unique()
unique_workbook_names_smde = df_boardex['Excel Workbook (SMDEs)'].unique()
unique_workbook_names = np.append(unique_workbook_names, unique_workbook_names_smde)

# %%
# Remove NaN (float) from an array of valid file names (strings) and NaN (float).
unique_workbook_names = unique_workbook_names[~pd.isnull(unique_workbook_names)]
unique_workbook_names
# Out:
# array(['Board Summary', 'Company Details',
#        'Director Profile - Characteristics',
#        'Director Profile - Education & Achievements', 'SMDEs Org Summary',
#        'SMDEs Profile - Characteristics',
#        'SMDEs Profile - Education & Achievements'], dtype=object)

# %%
inputfolder = Path(r"C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\output\boardex_sample_data\test")

# %%
# Use glob to return all excel files in the input directory
file_list = glob.glob(str(inputfolder) + "/*.xlsx")

# %%
# Convert the strings back into paths
file_list = [Path(file) for file in file_list]
file_list
# Out:
# [WindowsPath('C:/Users/jasonjia/Dropbox/Projects/boardex_and_execucomp/output/boardex_sample_data/test/Europe - Director Network - 55.xlsx'),
#  WindowsPath('C:/Users/jasonjia/Dropbox/Projects/boardex_and_execucomp/output/boardex_sample_data/test/Europe - Director Network - 66.xlsx'),
#  WindowsPath('C:/Users/jasonjia/Dropbox/Projects/boardex_and_execucomp/output/boardex_sample_data/test/Europe - SMDEs Network - 88.xlsx'),
#  WindowsPath('C:/Users/jasonjia/Dropbox/Projects/boardex_and_execucomp/output/boardex_sample_data/test/Europe - SMDEs Network - 99.xlsx'),
#  WindowsPath('C:/Users/jasonjia/Dropbox/Projects/boardex_and_execucomp/output/boardex_sample_data/test/Europe - SMDEs Profile - Characteristics - 2.xlsx'),
#  WindowsPath('C:/Users/jasonjia/Dropbox/Projects/boardex_and_execucomp/output/boardex_sample_data/test/Europe - SMDEs Profile - Education & Achievements.xlsx'),
#  WindowsPath('C:/Users/jasonjia/Dropbox/Projects/boardex_and_execucomp/output/boardex_sample_data/test/Europe - SMDEs Profile - Employment Current Board.xlsx'),
#  WindowsPath('C:/Users/jasonjia/Dropbox/Projects/boardex_and_execucomp/output/boardex_sample_data/test/Europe - SMDEs Profile - Employment Current NonBoard.xlsx'),
#  WindowsPath('C:/Users/jasonjia/Dropbox/Projects/boardex_and_execucomp/output/boardex_sample_data/test/Europe - SMDEs Profile - Employment Historical Board.xlsx'),
#  WindowsPath('C:/Users/jasonjia/Dropbox/Projects/boardex_and_execucomp/output/boardex_sample_data/test/Europe - SMDEs Profile - Employment Historical NonBoard - 1.xlsx'),
#  WindowsPath('C:/Users/jasonjia/Dropbox/Projects/boardex_and_execucomp/output/boardex_sample_data/test/Europe - SMDEs Profile - Employment Historical NonBoard - 2.xlsx'),
#  WindowsPath('C:/Users/jasonjia/Dropbox/Projects/boardex_and_execucomp/output/boardex_sample_data/test/Europe - SMDEs Profile - Other Activities.xlsx'),
#  WindowsPath('C:/Users/jasonjia/Dropbox/Projects/boardex_and_execucomp/output/boardex_sample_data/test/NA - Company Announcements.xlsx'),
#  WindowsPath('C:/Users/jasonjia/Dropbox/Projects/boardex_and_execucomp/output/boardex_sample_data/test/NA - Company Details.xlsx'),
#  WindowsPath('C:/Users/jasonjia/Dropbox/Projects/boardex_and_execucomp/output/boardex_sample_data/test/NA - Company Network - 11.xlsx'),
#  WindowsPath('C:/Users/jasonjia/Dropbox/Projects/boardex_and_execucomp/output/boardex_sample_data/test/ROW - Board Summary - 2.xlsx')]

# %%
# Define functions for main loop
def get_colstokeep(unique_workbook_name, df_boardex, sheet):
    list_colstokeep = []
    
    # Filter by unique_workbook_name
    if 'SMDE' in unique_workbook_name:
        df_boardex = df_boardex[df_boardex['Excel Workbook (SMDEs)'] == unique_workbook_name]
    else:
        df_boardex = df_boardex[df_boardex['Excel Workbook'] == unique_workbook_name]
        
    # Filter by sheet
    df_boardex = df_boardex[df_boardex['Sheet'] == sheet]

    # Get list of unique columns to keep
    list_colstokeep = list(df_boardex['Variable Name'].unique())
    
    return list_colstokeep

# %%
def get_sheetstoopen(unique_workbook_name, df_boardex):
    list_sheetstoopen = []
    
    # Filter by unique_workbook_name
    if 'SMDE' in unique_workbook_name:
        df_boardex = df_boardex[df_boardex['Excel Workbook (SMDEs)'] == unique_workbook_name]
    else:
        df_boardex = df_boardex[df_boardex['Excel Workbook'] == unique_workbook_name]
    
    # Get list of unique sheets to keep
    list_sheetstoopen = list(df_boardex['Sheet'].unique())
    
    return list_sheetstoopen

# %%
def get_df(filepath, sheet):
    row0 = pd.read_excel(filepath, sheet_name=sheet, header=None, nrows = 1, engine='openpyxl')
    pct_nan = round(pd.isna(row0).sum().mean() * 100, 1)
    if pct_nan > 0.5:
        print("% NaNs in first row:", pct_nan, "> 50%, taking header = row 1 by skipping row 0")
        df = pd.read_excel(filepath, sheet_name=sheet, header=1, engine='openpyxl')
    else:
        print("% NaNs in first row", pct_nan, "<= 50%, taking header = row 0 as usual")
        df = pd.read_excel(filepath, sheet_name=sheet, header=0, engine='openpyxl')
    
    return df

# %%
# Main loop
list_files_kept = []
list_files_not_kept = []
outputfolder = Path(r"C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\output\filter_boardex_by_cols")

for file in file_list:
    stem = file.stem
    name = file.name
    list_bools_workbook_names = [workbook_name in name for workbook_name in unique_workbook_names]

    if(any(list_bools_workbook_names)):
        # Keep track of list of files kept
        list_files_kept.append(name)
        print("File name (kept):", name)
        
        # Get the unique workbook name
        unique_workbook_name = list(compress(unique_workbook_names, list_bools_workbook_names))[0]
        print("Unique workbook name:", unique_workbook_name)
        
        # Check how many sheets need to be opened for this file.
        list_sheetstoopen = get_sheetstoopen(unique_workbook_name, df_boardex) 
        print("List of sheets to open:", list_sheetstoopen)
        num_sheets = len(list_sheetstoopen)
        
        for sheet in list_sheetstoopen:
            # Open the specific sheet in file
            print("------")
            print("Sheet:", sheet)
            df = get_df(file, sheet)
                        
            # Get columns to keep
            list_colstokeep = get_colstokeep(unique_workbook_name, df_boardex, sheet)
            
            # Strip/trim columns in list_colstokeep to maintain consistency
            list_colstokeep = [col.strip() for col in list_colstokeep]
            print("List of cols to keep:", list_colstokeep)

            # Strip/trim column headers of df to maintain consistency
            columns_dict = {}
            for column_header in df.columns:
                columns_dict[column_header] = column_header.strip() 
            df = df.rename(columns = columns_dict)
            
            # Filter by the columns we want
            df = df[list_colstokeep]
            
            # Save df
            outputfilename = stem + '_cols.xlsx'
            outputfilepath = Path(outputfolder / outputfilename)
            df.to_excel(outputfilepath, index=False)
            print("df saved to:", str(outputfilepath))
            
        print("-----------------------------------------------------------")
        
    else:
        # Keep track of list of files not kept
        list_files_not_kept.append(name)
# Out:
# File name (kept): Europe - SMDEs Profile - Characteristics - 2.xlsx
# Unique workbook name: SMDEs Profile - Characteristics
# List of sheets to open: ['Charcteristics']
# ------
# Sheet: Charcteristics
# % NaNs in first row: 73.3 > 50%, taking header = row 1 by skipping row 0
# List of cols to keep: ['DirectorID*', 'DOB']
# df saved to: C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\output\filter_boardex_by_cols\Europe - SMDEs Profile - Characteristics - 2_cols.xlsx
# -----------------------------------------------------------
# File name (kept): Europe - SMDEs Profile - Education & Achievements.xlsx
# Unique workbook name: SMDEs Profile - Education & Achievements
# List of sheets to open: ['Education', 'Achievements']
# ------
# Sheet: Education
# % NaNs in first row 0.0 <= 50%, taking header = row 0 as usual
# List of cols to keep: ['DirectorID*', 'Director Name', 'InstitutionID*', 'Institution Name', 'Company Type', 'Qualification', 'Qualification Description', 'Qualification Date']
# df saved to: C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\output\filter_boardex_by_cols\Europe - SMDEs Profile - Education & Achievements_cols.xlsx
# ------
# Sheet: Achievements
# % NaNs in first row 0.0 <= 50%, taking header = row 0 as usual
# List of cols to keep: ['Country', 'DirectorID*', 'Director Name', 'OrganisationID*', 'OrganisationName', 'Achievement Date', 'Award/Achievement']
# df saved to: C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\output\filter_boardex_by_cols\Europe - SMDEs Profile - Education & Achievements_cols.xlsx
# -----------------------------------------------------------
# File name (kept): NA - Company Details.xlsx
# Unique workbook name: Company Details
# List of sheets to open: ['Company Details']
# ------
# Sheet: Company Details
# % NaNs in first row 0.0 <= 50%, taking header = row 0 as usual
# List of cols to keep: ['CompanyID*', 'Bankers']
# df saved to: C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\output\filter_boardex_by_cols\NA - Company Details_cols.xlsx
# -----------------------------------------------------------
# File name (kept): ROW - Board Summary - 2.xlsx
# Unique workbook name: Board Summary
# List of sheets to open: ['Board Summary']
# ------
# Sheet: Board Summary
# % NaNs in first row: 82.2 > 50%, taking header = row 1 by skipping row 0
# List of cols to keep: ['Annual Report Year', 'CompanyID*', 'Company Name', 'ISIN', 'Sector', 'Director Type (ED or SD)', 'DirectorID*', 'Individual Name', 'Individual Role', 'Time in Role', 'Time on Board', 'Time in Company', 'Total Number of Quoted Boards to Date', 'Age (Yrs)', 'Gender', 'Nationality Mix', 'Bonus/ (Bonus&Salary)', 'Equity Linked/ Total', 'Performance/ Total', 'Total Directors on the Board', 'Salary', 'Total Annual Compensation ']
# df saved to: C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\output\filter_boardex_by_cols\ROW - Board Summary - 2_cols.xlsx
# -----------------------------------------------------------

# %%
# Print list of files kept and not kept
print("List of files kept:", list_files_kept)
print("------")
print("List of files not kept:", list_files_not_kept)
# Out:
# List of files kept: ['Europe - SMDEs Profile - Characteristics - 2.xlsx', 'Europe - SMDEs Profile - Education & Achievements.xlsx', 'NA - Company Details.xlsx', 'ROW - Board Summary - 2.xlsx']
# ------
# List of files not kept: ['Europe - Director Network - 55.xlsx', 'Europe - Director Network - 66.xlsx', 'Europe - SMDEs Network - 88.xlsx', 'Europe - SMDEs Network - 99.xlsx', 'Europe - SMDEs Profile - Employment Current Board.xlsx', 'Europe - SMDEs Profile - Employment Current NonBoard.xlsx', 'Europe - SMDEs Profile - Employment Historical Board.xlsx', 'Europe - SMDEs Profile - Employment Historical NonBoard - 1.xlsx', 'Europe - SMDEs Profile - Employment Historical NonBoard - 2.xlsx', 'Europe - SMDEs Profile - Other Activities.xlsx', 'NA - Company Announcements.xlsx', 'NA - Company Network - 11.xlsx']

# %%
list_test = ['a b ', 'b', 'c']

# %%
.strip()

# %%
for i, j in enumerate(list_test):
    print("<" + j.strip() + ">")
# Out:
# <a b>
# <b>
# <c>

# %%
df
# Out:
#      Annual Report Year  CompanyID*  \
# 0               Current  9912158216
# 1               Current  9912158216
# 2               Current  9912158216
# 3               Current  9912158216
# 4               Current  9912158216
# ...                 ...         ...
# 6875           Dec 2015  9987168930
# 6876           Dec 2015  9987168930
# 6877           Dec 2015  9987168930
# 6878           Dec 2015  9987168930
# 6879           Dec 2015  9987168930
#
#                                           Company Name          ISIN  \
# 0                                        ABB INDIA LTD  INE117A01022
# 1                                        ABB INDIA LTD  INE117A01022
# 2                                        ABB INDIA LTD  INE117A01022
# 3                                        ABB INDIA LTD  INE117A01022
# 4                                        ABB INDIA LTD  INE117A01022
# ...                                                ...           ...
# 6875  WUXI PHARMATECH (CAYMAN) INC (De-listed 12/2015)  US9293521020
# 6876  WUXI PHARMATECH (CAYMAN) INC (De-listed 12/2015)  US9293521020
# 6877  WUXI PHARMATECH (CAYMAN) INC (De-listed 12/2015)  US9293521020
# 6878  WUXI PHARMATECH (CAYMAN) INC (De-listed 12/2015)  US9293521020
# 6879  WUXI PHARMATECH (CAYMAN) INC (De-listed 12/2015)  US9293521020
#
#                                  Sector Director Type (ED or SD)  \
# 0               Engineering & Machinery                       ED
# 1               Engineering & Machinery                       SD
# 2               Engineering & Machinery                       SD
# 3               Engineering & Machinery                       SD
# 4               Engineering & Machinery                       SD
# ...                                 ...                      ...
# 6875  Pharmaceuticals and Biotechnology                       SD
# 6876  Pharmaceuticals and Biotechnology                       SD
# 6877  Pharmaceuticals and Biotechnology                       SD
# 6878  Pharmaceuticals and Biotechnology                       SD
# 6879  Pharmaceuticals and Biotechnology                       SD
#
#        DirectorID*                 Individual Name       Individual Role  \
# 0     170894010222                  Sanjeev Sharma                CEO/MD
# 1      22338344934                   Morten Wierod              Chairman
# 2       6634566074                 Renu Sud Karnad       Independent NED
# 3       6936339228        Darius Erachshaw Udwadia       Independent NED
# 4      81569710823  Vegulaparanan Kasi Viswanathan       Independent NED
# ...            ...                             ...                   ...
# 6875   84153612711             Kian-Wee (Hua) Seah  Independent Director
# 6876   11865494486         Teh-Ming (Walter) Kwauk  Independent Director
# 6877   20267811575                   Stewart J Hen  Independent Director
# 6878    6831268246             Xuesong (Jeff) Leng  Independent Director
# 6879   11074602880           William Robert Keller  Independent Director
#
#      Time in Role  ... Total Number of Quoted Boards to Date Age (Yrs) Gender  \
# 0             5.3  ...                                     2        55      M
# 1             0.2  ...                                     1        49      M
# 2             7.7  ...                                    16        69      F
# 3            15.8  ...                                    13        81      M
# 4             1.4  ...                                     7        70      M
# ...           ...  ...                                   ...       ...    ...
# 6875          n.a  ...                                   n.a       n.a    n.a
# 6876          n.a  ...                                   n.a       n.a    n.a
# 6877          n.a  ...                                   n.a       n.a    n.a
# 6878          n.a  ...                                   n.a       n.a    n.a
# 6879          n.a  ...                                   n.a       n.a    n.a
#
#      Nationality Mix Bonus/ (Bonus&Salary) Equity Linked/ Total  \
# 0             Indian                   n.a                  n.a
# 1                n.a                   n.a                  n.a
# 2             Indian                   n.a                  n.a
# 3             Indian                   n.a                  n.a
# 4             Indian                   n.a                  n.a
# ...              ...                   ...                  ...
# 6875             n.a                   n.a                  n.a
# 6876             n.a                   n.a                  n.a
# 6877             n.a                   n.a                  n.a
# 6878             n.a                   n.a                  n.a
# 6879             n.a                   n.a                  n.a
#
#      Performance/ Total Total Directors on the Board Salary  \
# 0                   n.a                            6    n.a
# 1                   n.a                            6    n.a
# 2                   n.a                            6    n.a
# 3                   n.a                            6    n.a
# 4                   n.a                            6    n.a
# ...                 ...                          ...    ...
# 6875                n.a                            9    n.a
# 6876                n.a                            9    n.a
# 6877                n.a                            9    n.a
# 6878                n.a                            9    n.a
# 6879                n.a                            9    n.a
#
#       Total Annual Compensation
# 0                            n.a
# 1                            n.a
# 2                            n.a
# 3                            n.a
# 4                            n.a
# ...                          ...
# 6875                         n.a
# 6876                         n.a
# 6877                         n.a
# 6878                         n.a
# 6879                         n.a
#
# [6880 rows x 22 columns]
