# %%
import pandas as pd
from pathlib import Path
import os

# %%
inputpath = Path(r"C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\isins.xlsx")
outputpath = Path(r"C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp")

# %%
# Read excel
isin = pd.read_excel(inputpath)

# %%
# Drop na
isin = isin['ISIN'].dropna()

# %%
isin_list = list(isin)
isin_list
# Out:
# ['GB00BJVJZD68',
#  'IE00BLP1HW54',
#  'IE00B40K9117',
#  'IE00B8KQN827',
#  'US4527045052',
#  'CA4532584022',
#  'US7132781094',
#  'PHY7072Q1032',
#  'US69344D4088',
#  'GB00B6SLMV12',
#  'US1281951046',
#  'US8798681073',
#  'US9433151019',
#  'BMG9618E1075',
#  'LU0914713705',
#  'GB00BDCPN049',
#  'US4566071001',
#  'US4566072090',
#  'CA5899751013',
#  'GB0031215220',
#  'PA1436583006',
#  'US14365C1036',
#  'US9343904028',
#  'US30603D1090',
#  'BMG0464B1072',
#  'NL0000300838',
#  'US63975K1043',
#  'ZAE000004875',
#  'US8531182066',
#  'ZAE000109815',
#  'US00400T1025',
#  'ZAE000255915',
#  'ZAE000190724',
#  'FR0013326246',
#  'US9045871020',
#  'CA8310211005',
#  'US9109091002',
#  'US82575P1075',
#  'ZAE000259701',
#  'ZAE000054045',
#  'MHY621321089',
#  'MHY481251012',
#  'US38059T1060',
#  'ZAE000018123',
#  'MHY0207T1001',
#  'BMG8192H1060',
#  'BMG3198U1027',
#  'BMG1190F1077',
#  'MHY2188B1083',
#  'US8794037072',
#  'US8794037809',
#  'US0351282068',
# ...

# %%
contains_list = []

# %%
# for file in directory:

# %%
directory = r"C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp"

# %%
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    if Path(f).suffix == '.xlsx':
        print(f)
# Out:
# C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\isins.xlsx
# C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\List of Variables for Boardex and Execucomp 030322.xlsx

# %%
df = pd.read_excel("...")

# %%
df.str.contains('|'.join(isin_list), case=False)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 4135    True
# 4136    True
# 4137    True
# 4138    True
# 4139    True
# Name: ISIN, Length: 4109, dtype: bool

# %%
if df.str.contains('|'.join(check_list), case=False).sum() > 0:
    contains_list.append(1)
else:
    contains_list.append(0)
print(contains_list)
# Out:
# [1, 1]
