# %%
import pandas as pd
from pathlib import Path

# %%
inputpath = Path(r"C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\output\gvkey_to_country\gvkey_to_country.sas7bdat")
outputpath = Path(r"C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\output\gvkey_to_country\gvkey_to_country.xlsx")

# %%
def convert_sas7bdat_to_excel(inputpath, outputpath):
    df = pd.read_sas(inputpath)
    for i in df:
        if df[i].dtype == 'O':
            df[i] = df[i].str.decode('UTF-8')
    df.to_excel(outputpath, index=False)
    return df

# %%
df = convert_sas7bdat_to_excel(inputpath, outputpath)

# %%
df
# Out:
#        GVKEY   DATADATE   FYEAR  LOC  FIC
# 0     001166 2020-12-31  2020.0  NLD  NLD
# 1     001166 2021-12-31  2021.0  NLD  NLD
# 2     001932 2020-12-31  2020.0  GBR  GBR
# 3     001932 2021-12-31  2021.0  GBR  GBR
# 4     002410 2020-12-31  2020.0  GBR  GBR
# ...      ...        ...     ...  ...  ...
# 1548  325693 2021-12-31  2021.0  FRA  FRA
# 1549  326213 2020-12-31  2020.0  ARE  ARE
# 1550  326213 2021-12-31  2021.0  ARE  ARE
# 1551  331614 2020-12-31  2020.0  ITA  ITA
# 1552  331614 2021-12-31  2021.0  ITA  ITA
#
# [1553 rows x 5 columns]
