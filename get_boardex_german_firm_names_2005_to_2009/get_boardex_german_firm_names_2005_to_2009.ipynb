# %%
# Import Packages
import pandas as pd, numpy as np
import os, sys, glob, re
from pathlib import Path
from itertools import compress

# %%
pd.set_option("display.max_columns", None)
# pd.set_option("display.max_rows", None)

# %%
inputfilepath = Path(r"C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\output\filter_boardex_by_cols\output_from_mercury_combined_fragment_country_and_managementtype\Board Summary_director_and_smde.csv")

# %%
df = pd.read_csv(inputfilepath, low_memory=False)
df
# Out:
#         Annual Report Year                   Country  CompanyID*  \
# 0                  Current                    Jersey  9811997164
# 1                  Current                    Jersey  9811997164
# 2                  Current                    Jersey  9811997164
# 3                  Current                    Jersey  9811997164
# 4                  Current                    Jersey  9811997164
# ...                    ...                       ...         ...
# 1568524           Jun 2016  United Kingdom - England  8113811537
# 1568525           Jun 2016  United Kingdom - England  8113811537
# 1568526           Jun 2016  United Kingdom - England  8113811537
# 1568527           Jun 2016  United Kingdom - England  8113811537
# 1568528           Jun 2016  United Kingdom - England  8113811537
#
#                                               Company Name          ISIN  \
# 0        3I INFRASTRUCTURE PLC (3i Infrastructure Ltd p...  JE00BF5FX167
# ...

# %%
# Unique values of country
df['Country'].unique()
# Out:
# array(['Jersey', 'Denmark', 'Italy', 'Germany', 'Switzerland', 'Spain',
#        'Republic Of Ireland', 'France', 'Luxembourg', 'Netherlands',
#        'Turkey', 'Norway', 'Poland', 'Greece', 'Russian Federation',
#        'Guernsey', 'Belgium', 'Sweden', 'United Kingdom - England',
#        'Portugal', 'Austria', 'Czech Republic', 'Finland', 'Monaco',
#        'Isle Of Man', 'Cyprus', 'Ukraine', 'United States', 'Canada',
#        'Bermuda', 'Cayman Islands', 'Singapore', 'China', 'Australia',
#        'Philippines', 'South Africa', 'United Arab Emirates', 'India',
#        'Brazil', 'Hong Kong SAR', 'New Zealand', 'Japan', 'Mexico',
#        'Virgin Islands U.S.', 'Malaysia', 'Taiwan Territory of',
#        'Virgin Islands British', 'Israel', 'Argentina', 'Colombia',
#        'Chile', 'Panama', 'Thailand', 'Peru', 'Puerto Rico', 'Egypt',
#        'Kazakhstan', 'South Korea', 'Pakistan', 'Kuwait', 'Indonesia',
# ...

# %%
df = df[df['Country'] == 'Germany']
df
# Out:
#         Annual Report Year  Country  CompanyID*  \
# 501                Current  Germany   947432828
# 502                Current  Germany   947432828
# 503                Current  Germany   947432828
# 504                Current  Germany   947432828
# 505                Current  Germany   947432828
# ...                    ...      ...         ...
# 1561905           Sep 2020  Germany   329218940
# 1561906           Sep 2020  Germany   329218940
# 1561907           Sep 2020  Germany   329218940
# 1561908           Sep 2020  Germany   329218940
# 1561909           Sep 2020  Germany   329218940
#
#                                Company Name          ISIN            Sector  \
# 501                          AAREAL BANK AG  DE0005408116             Banks
# 502                          AAREAL BANK AG  DE0005408116             Banks
# 503                          AAREAL BANK AG  DE0005408116             Banks
# 504                          AAREAL BANK AG  DE0005408116             Banks
# ...

# %%
df['Annual Report Year'].unique()
# Out:
# array(['Current', 'Dec 2002', 'Dec 2003', 'Dec 2004', 'Dec 2005',
#        'Dec 2006', 'Dec 2007', 'Dec 2008', 'Dec 2009', 'Dec 2010',
#        'Dec 2011', 'Dec 2012', 'Dec 2013', 'Dec 2014', 'Dec 2015',
#        'Dec 2016', 'Dec 2017', 'Dec 2018', 'Dec 2019', 'Dec 1999',
#        'Dec 2000', 'Dec 2001', 'Sep 2010', 'Sep 1999', 'Sep 2000',
#        'Sep 2001', 'Sep 2002', 'Sep 2003', 'Sep 2004', 'Sep 2005',
#        'Sep 2006', 'Sep 2007', 'Sep 2008', 'Sep 2009', 'Sep 2011',
#        'Sep 2012', 'Sep 2013', 'Sep 2014', 'Sep 2015', 'Sep 2016',
#        'Sep 2017', 'Sep 2018', 'Sep 2019', 'Sep 2020', 'Dec 2020',
#        'Nov 2020', 'Mar 2012', 'Mar 2013', 'Mar 2014', 'Oct 2010',
#        'Oct 2011', 'Oct 2012', 'Oct 2013', 'Oct 2014', 'Aug 2014',
#        'Mar 2010', 'Mar 2011', 'Mar 2015', 'Mar 2016', 'Mar 2017',
#        'Mar 2018', 'Mar 2019', 'Mar 2020', 'Apr 2019', 'Jun 2001',
#        'Jan 2014'], dtype=object)

# %%
# Filter by year
years = ['2005', '2006', '2007', '2008', '2009']

# %%
df = df[df['Annual Report Year'].str.contains('|'.join(years))]
df['Annual Report Year'].unique()
# Out:
# array(['Dec 2005', 'Dec 2006', 'Dec 2007', 'Dec 2008', 'Dec 2009',
#        'Sep 2005', 'Sep 2006', 'Sep 2007', 'Sep 2008', 'Sep 2009'],
#       dtype=object)

# %%
df
# Out:
#         Annual Report Year  Country  CompanyID*  \
# 597               Dec 2005  Germany   947432828
# 598               Dec 2005  Germany   947432828
# 599               Dec 2005  Germany   947432828
# 600               Dec 2005  Germany   947432828
# 601               Dec 2005  Germany   947432828
# ...                    ...      ...         ...
# 1561734           Sep 2009  Germany   329218940
# 1561735           Sep 2009  Germany   329218940
# 1561736           Sep 2009  Germany   329218940
# 1561737           Sep 2009  Germany   329218940
# 1561738           Sep 2009  Germany   329218940
#
#                                Company Name          ISIN            Sector  \
# 597                          AAREAL BANK AG  DE0005408116             Banks
# 598                          AAREAL BANK AG  DE0005408116             Banks
# 599                          AAREAL BANK AG  DE0005408116             Banks
# 600                          AAREAL BANK AG  DE0005408116             Banks
# ...

# %%
german_firms_byname = df.drop_duplicates(subset=['Company Name'], ignore_index=True)
german_firms_byname
# Out:
#    Annual Report Year  Country   CompanyID*  \
# 0            Dec 2005  Germany    947432828
# 1            Dec 2005  Germany     34078759
# 2            Dec 2007  Germany  10574851006
# 3            Dec 2005  Germany    363910044
# 4            Sep 2005  Germany    298636047
# 5            Dec 2005  Germany    665510163
# 6            Dec 2005  Germany    673410629
# 7            Dec 2005  Germany     75576620
# 8            Sep 2005  Germany   6397451141
# 9            Dec 2005  Germany    116937854
# 10           Dec 2005  Germany   1219311313
# 11           Dec 2005  Germany    138413321
# 12           Dec 2005  Germany    138473434
# 13           Dec 2005  Germany    138503478
# 14           Dec 2005  Germany    138583607
# 15           Dec 2005  Germany    138633691
# 16           Dec 2007  Germany    138643712
# 17           Dec 2007  Germany   8986299164
# 18           Dec 2005  Germany   1465410847
# 19           Dec 2005  Germany   1483311951
# ...

# %%
german_firms_byisin = df.drop_duplicates(subset=['ISIN'], ignore_index=True)
german_firms_byisin
# Out:
#    Annual Report Year  Country   CompanyID*  \
# 0            Dec 2005  Germany    947432828
# 1            Dec 2005  Germany     34078759
# 2            Dec 2007  Germany  10574851006
# 3            Dec 2005  Germany    363910044
# 4            Sep 2005  Germany    298636047
# 5            Dec 2005  Germany    665510163
# 6            Dec 2005  Germany    673410629
# 7            Dec 2005  Germany     75576620
# 8            Sep 2005  Germany   6397451141
# 9            Dec 2005  Germany    116937854
# 10           Dec 2005  Germany   1219311313
# 11           Dec 2005  Germany    138413321
# 12           Dec 2005  Germany    138473434
# 13           Dec 2005  Germany    138503478
# 14           Dec 2005  Germany    138583607
# 15           Dec 2005  Germany    138633691
# 16           Dec 2007  Germany    138643712
# 17           Dec 2007  Germany   8986299164
# 18           Dec 2005  Germany   1465410847
# 19           Dec 2005  Germany   1483311951
# ...

# %%
# They are the same, so we can safely save them (after filtering relevant columns).
german_firms_byisin = german_firms_byisin[['Annual Report Year', 'Country','Company Name','ISIN']]
german_firms_byisin.to_excel(r"C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\output\boardex_german_firm_names_2005_to_2009\boardex_german_firm_names_2005_to_2009.xlsx", index=False)
