# %%
# Import Packages
import pandas as pd, numpy as np
from pathlib import Path
import os, sys, glob, re

# %%
inputfilepath = Path(r"C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\output\wvs\WVS_Cross-National_Wave_7_stata_v3_0.csv")

# %%
df = pd.read_csv(inputfilepath, low_memory=False)
df
# Out:
#                   version                        doi         A_WAVE  A_YEAR  \
# 0      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 1      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 2      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 3      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 4      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# ...                   ...                        ...            ...     ...
# 84633  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2020
# 84634  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2020
# 84635  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2020
# 84636  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2020
# 84637  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2020
#
# ...

# %%
df2 = pd.read_excel(r"C:\Users\jasonjia\Dropbox\Projects\boardex_and_execucomp\output\boardex_list_of_unique_values\nationality.xlsx")
df2
# Out:
#     Boardex Nationality            Country Check if Country Exists ISO Code  \
# 0                Afghan        Afghanistan             Afghanistan      AFG
# 1              Albanian            Albania                     NaN      NaN
# 2              Algerian            Algeria                 Algeria      DZA
# 3              American      United States           United States      USA
# 4               Angolan             Angola                     NaN      NaN
# ..                  ...                ...                     ...      ...
# 187   Wallisian/Futunan  Wallis and Futuna                     NaN      NaN
# 188              Yemeni              Yemen                     NaN      NaN
# 189             Zambian             Zambia                     NaN      NaN
# 190          Zimbabwean           Zimbabwe                Zimbabwe      ZWE
# 191                 NaN                NaN                     NaN      NaN
#
#      Match
# 0        1
# 1        0
# 2        1
# ...

# %%
merge1 = df.merge(df2, left_on = 'B_COUNTRY', right_on = 'Check if Country Exists', how='left')
merge1
# Out:
#                   version                        doi         A_WAVE  A_YEAR  \
# 0      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 1      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 2      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 3      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 4      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# ...                   ...                        ...            ...     ...
# 84633  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2020
# 84634  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2020
# 84635  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2020
# 84636  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2020
# 84637  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2020
#
# ...

# %%
merge1[merge1['Country'].isna()]
# Out:
#                   version                        doi         A_WAVE  A_YEAR  \
# 0      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 1      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 2      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 3      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 4      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# ...                   ...                        ...            ...     ...
# 77143  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2019
# 77144  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2019
# 77145  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2019
# 77146  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2019
# 77147  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2019
#
# ...

# %%
merge2 = df.merge(df2, left_on = 'B_COUNTRY', right_on = 'Country', how='left')
merge2
# Out:
#                   version                        doi         A_WAVE  A_YEAR  \
# 0      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 1      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 2      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 3      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 4      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# ...                   ...                        ...            ...     ...
# 84633  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2020
# 84634  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2020
# 84635  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2020
# 84636  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2020
# 84637  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2020
#
# ...

# %%
merge2[merge2['Country'].isna()]
# Out:
#                   version                        doi         A_WAVE  A_YEAR  \
# 0      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 1      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 2      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 3      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# 4      3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2018
# ...                   ...                        ...            ...     ...
# 77143  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2019
# 77144  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2019
# 77145  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2019
# 77146  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2019
# 77147  3-0-0 (2022-03-01)  doi.org/10.14281/18241.16  WVS 2017-2021    2019
#
# ...
