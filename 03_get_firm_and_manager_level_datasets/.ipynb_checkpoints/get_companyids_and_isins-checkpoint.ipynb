# %%
# Import Packages
import pandas as pd, numpy as np
from pathlib import Path
import os, sys, glob, re

# %% [markdown]
# # Define input and output files

# %%
def parent_dir(dir):
    return os.path.abspath(os.path.join(dir, os.pardir))

# %%
# Define input folder containing output from combined BoardEx files
inputfilepath = Path(parent_dir(parent_dir(os.getcwd())) / Path('output/02_get_initial_datasets/02.2_boardex_combined/Board Summary.csv'))
print('inputfilepath:', inputfilepath, inputfilepath.__class__)
# Define output folder containing firm-level dataset
outputfilepath = Path(parent_dir(parent_dir(os.getcwd())) / Path('output/03_get_firm_and_manager_level_datasets/board_summary_isins.txt'))
print('outputfilepath:', outputfilepath, outputfilepath.__class__)
# Out:
# inputfilepath: C:\Users\jasonjia\Dropbox\projects\manager_and_board_characteristics\Board Charac_Jason\output\02_get_initial_datasets\02.2_boardex_combined\Board Summary.csv <class 'pathlib.WindowsPath'>
# outputfilepath: C:\Users\jasonjia\Dropbox\projects\manager_and_board_characteristics\Board Charac_Jason\output\03_get_firm_and_manager_level_datasets\board_summary_isins.txt <class 'pathlib.WindowsPath'>

# %% [markdown]
# # Import Board Summary

# %%
df = pd.read_csv(inputfilepath, low_memory=False)
df
# Out:
#          Ratios - Wealth Delta  Total - Total Annual Compensation  \
# 0                          2.0                                NaN
# 1                          0.0                                NaN
# 2                          1.0                                NaN
# 3                          NaN                                NaN
# 4                          1.0                                NaN
# ...                        ...                                ...
# 1568524                    NaN                                NaN
# 1568525                    NaN                                NaN
# 1568526                    NaN                                NaN
# 1568527                    NaN                                NaN
# 1568528                    NaN                                NaN
#
#         Annual Report Year  \
# 0                  Current
# 1                  Current
# 2                  Current
# 3                  Current
# 4                  Current
# ...                    ...
# 1568524           Jun 2016
# 1568525           Jun 2016
# 1568526           Jun 2016
# 1568527           Jun 2016
# 1568528           Jun 2016
#
#          Annual- Equity Linked Options - Intrinsic Options (excercisable)  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1568524                                                NaN
# 1568525                                                NaN
# 1568526                                                NaN
# 1568527                                                NaN
# 1568528                                                NaN
#
#         Director Type  Characteristics of Roles - Time on Board  \
# 0                  SD                                       3.2
# 1                  SD                                       1.2
# 2                  SD                                       8.0
# 3                  SD                                       6.9
# 4                  SD                                       6.3
# ...               ...                                       ...
# 1568524            SM                                       NaN
# 1568525            SM                                       NaN
# 1568526            SM                                       NaN
# 1568527            SM                                       NaN
# 1568528            SM                                       NaN
#
#          Accumulated Wealth - LTIPS(max)  Ratios - Bonus/ (Bonus&Salary)  \
# 0                                    NaN                             NaN
# 1                                    NaN                             NaN
# 2                                    NaN                             NaN
# 3                                    NaN                             NaN
# 4                                    NaN                             NaN
# ...                                  ...                             ...
# 1568524                              NaN                             NaN
# 1568525                              NaN                             NaN
# 1568526                              NaN                             NaN
# 1568527                              NaN                             NaN
# 1568528                              NaN                             NaN
#
#          Annual- Equity Linked Options - Total Equity Linked Compensation  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1568524                                                NaN
# 1568525                                                NaN
# 1568526                                                NaN
# 1568527                                                NaN
# 1568528                                                NaN
#
#          Annual- Equity Linked Options - Share Price  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
# ...                                              ...  ...
# 1568524                                          NaN  ...
# 1568525                                          NaN  ...
# 1568526                                          NaN  ...
# 1568527                                          NaN  ...
# 1568528                                          NaN  ...
#
#                        Sector  \
# 0        Investment Companies
# 1        Investment Companies
# 2        Investment Companies
# 3        Investment Companies
# 4        Investment Companies
# ...                       ...
# 1568524     Business Services
# 1568525     Business Services
# 1568526     Business Services
# 1568527     Business Services
# 1568528     Business Services
#
#          Director Experience - Total Number of Quoted Current Boards  \
# 0                                                      2.0
# 1                                                      2.0
# 2                                                      1.0
# 3                                                      1.0
# 4                                                      1.0
# ...                                                    ...
# 1568524                                                NaN
# 1568525                                                NaN
# 1568526                                                NaN
# 1568527                                                NaN
# 1568528                                                NaN
#
#          Characteristics of Roles - Time in Role  \
# 0                                            3.2
# 1                                            1.2
# 2                                            4.3
# 3                                            6.9
# 4                                            6.3
# ...                                          ...
# 1568524                                      NaN
# 1568525                                      NaN
# 1568526                                      NaN
# 1568527                                      NaN
# 1568528                                      NaN
#
#          Director Experience - Gender           inputfilestem  region  \
# 0                                   M  Europe - Board Summary  Europe
# 1                                   F  Europe - Board Summary  Europe
# 2                                   M  Europe - Board Summary  Europe
# 3                                   M  Europe - Board Summary  Europe
# 4                                   M  Europe - Board Summary  Europe
# ...                               ...                     ...     ...
# 1568524                           NaN  UK - SMDEs Org Summary      UK
# 1568525                           NaN  UK - SMDEs Org Summary      UK
# 1568526                           NaN  UK - SMDEs Org Summary      UK
# 1568527                           NaN  UK - SMDEs Org Summary      UK
# 1568528                           NaN  UK - SMDEs Org Summary      UK
#
#          mgmt_type      workbook_name  fragment_number  sheet_name
# 0         Director      Board Summary              NaN         NaN
# 1         Director      Board Summary              NaN         NaN
# 2         Director      Board Summary              NaN         NaN
# 3         Director      Board Summary              NaN         NaN
# 4         Director      Board Summary              NaN         NaN
# ...            ...                ...              ...         ...
# 1568524       SMDE  SMDEs Org Summary              NaN         NaN
# 1568525       SMDE  SMDEs Org Summary              NaN         NaN
# 1568526       SMDE  SMDEs Org Summary              NaN         NaN
# 1568527       SMDE  SMDEs Org Summary              NaN         NaN
# 1568528       SMDE  SMDEs Org Summary              NaN         NaN
#
# [1568529 rows x 62 columns]

# %% [markdown]
# # Get list of unique ISINs, company IDs and company names

# %%
print('Number of unique (ISIN) combinations:', df[['ISIN']].drop_duplicates().shape[0])
print('Number of unique (ISIN, Company ID) combinations:', df[['ISIN', 'CompanyID*']].drop_duplicates().shape[0])
print('Number of unique (ISIN, Company Name) combinations:', df[['ISIN', 'Company Name']].drop_duplicates().shape[0])
print('Number of unique (Company ID) combinations:', df[['CompanyID*']].drop_duplicates().shape[0])
print('Number of unique (Company ID, Company Name) combinations:', df[['CompanyID*', 'Company Name']].drop_duplicates().shape[0])
print('Number of unique (Company Name) combinations:', df[['Company Name']].drop_duplicates().shape[0])
print('Number of unique (ISIN, Company ID, Company Name) combinations:', df[['ISIN', 'CompanyID*', 'Company Name']].drop_duplicates().shape[0])
# Out:
# Number of unique (ISIN) combinations: 3226
# Number of unique (ISIN, Company ID) combinations: 3249
# Number of unique (ISIN, Company Name) combinations: 3249
# Number of unique (Company ID) combinations: 3249
# Number of unique (Company ID, Company Name) combinations: 3249
# Number of unique (Company Name) combinations: 3249
# Number of unique (ISIN, Company ID, Company Name) combinations: 3249

# %%
# View df of unique (ISIN, Company ID, Company Name) combinations
df[['CompanyID*', 'ISIN', 'Company Name']].drop_duplicates()
# Out:
#          CompanyID*          ISIN  \
# 0        9811997164  JE00BF5FX167
# 97       3552310896  DK0010253921
# 201        24982801  IT0001233417
# 501       947432828  DE0005408116
# 855        14501792  CH0012221716
# ...             ...           ...
# 533982    837912719  GB0031698896
# 534131    428697608  GB00B67G5X01
# 534325  24259147400  GB00BYYK2V80
# 534349    429577695  JE00B8KF9B49
# 534670   8113811537  GB00B1VK7X76
#
#                                              Company Name
# 0       3I INFRASTRUCTURE PLC (3i Infrastructure Ltd p...
# 97                                        A/S SCHOUW & CO
# 201                                               A2A SPA
# 501                                        AAREAL BANK AG
# 855                                               ABB LTD
# ...                                                   ...
# 533982                                   WILLIAM HILL PLC
# 534131  WORKSPACE GROUP PLC (London Industrial PLC pri...
# 534325             WORLDPAY GROUP PLC (De-listed 01/2018)
# 534349               WPP PLC (WPP Group prior to 11/2008)
# 534670                  XCHANGING PLC (De-listed 06/2016)
#
# [3249 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Ratios - Wealth Delta', 'Total - Total Annual Compensation',
#        'Annual Report Year',
#        'Annual- Equity Linked Options - Intrinsic Options (excercisable)',
#        'Director Type', 'Characteristics of Roles - Time on Board',
#        'Accumulated Wealth - LTIPS(max)', 'Ratios - Bonus/ (Bonus&Salary)',
#        'Annual- Equity Linked Options - Total Equity Linked Compensation',
#        'Annual- Equity Linked Options - Share Price', 'Individual Name',
#        'Annual- Equity Linked Options - LTIPS(max)',
#        'Director Experience - Total Number of Private Current Boards',
#        'Annual Direct Compensation - Salary',
#        'Director Experience - Total Number of Other Current Boards',
#        'DirectorID*', 'Accumulated Wealth - Intrinsic Option',
#        'Accumulated Wealth - Estimated Option',
#        'Annual Direct Compensation - Total Salary+Bonus',
#        'Annual- Equity Linked Options - Shares',
#        'Director Experience - Nationality Mix', 'Index', 'Ticker',
#        'Director Experience - Total Number of Private Boards to Date',
#        'CompanyID*', 'Accumulated Wealth - Liquid Wealth',
#        'Annual Direct Compensation - Total Inc. D.C. Pension & Other',
#        'Annual- Equity Linked Options - Intrinsic Options (unexercisable)',
#        'Director Experience - Total Number of Quoted Boards to Date',
#        'Ratios - %Change from Last Period', 'Total Wealth - Total Wealth',
#        'Country', 'Annual Direct Compensation - Bonus',
#        'Ratios - Performance/ Total',
#        'Director Experience - Number of Qualifications',
#        'Director Experience - Age (Yrs)', 'Company Name',
#        'Annual- Equity Linked Options - Estimated Options (unexcercisable)',
#        'Annual- Equity Linked Options - Vesting Date',
#        'Director Experience - Avg. Yrs on Other Quoted Boards',
#        'Characteristics of Roles - Individual Role',
#        'Annual Direct Compensation - D.C Pension',
#        'Characteristics of Roles - Director Network Size',
#        'Director Experience - Total Number of Other Boards to Date',
#        'Annual- Equity Linked Options - Estimated Options (exercisable)',
#        'Annual Direct Compensation - Other', 'Accumulated Wealth - Shares',
#        'Characteristics of Roles - Time to Retirement',
#        'Director Count Totals - Number of Independent NED with past CFO/FD role',
#        'ISIN', 'Ratios - Equity Linked/ Total',
#        'Characteristics of Roles - Time in Company', 'Sector',
#        'Director Experience - Total Number of Quoted Current Boards',
#        'Characteristics of Roles - Time in Role',
#        'Director Experience - Gender', 'inputfilestem', 'region', 'mgmt_type',
#        'workbook_name', 'fragment_number', 'sheet_name'],
#       dtype='object')

# %%
# Get df of unique ISINs
df_output = df[['ISIN']].drop_duplicates()

# Some rows have two or more ISINs separated by ','. Take only the first ISIN using regex.
df_output['ISIN'] = df_output['ISIN'].str.split(',').str[0]

# Save as txt file (to be fed into WRDS later on)
df_output.to_csv(outputfilepath, index=False, header=False)
df_output
# Out:
#                 ISIN
# 0       JE00BF5FX167
# 97      DK0010253921
# 201     IT0001233417
# 501     DE0005408116
# 855     CH0012221716
# ...              ...
# 533982  GB0031698896
# 534131  GB00B67G5X01
# 534325  GB00BYYK2V80
# 534349  JE00B8KF9B49
# 534670  GB00B1VK7X76
#
# [3226 rows x 1 columns]

# %% [markdown]
# # Next steps: Map firm identifier (e.g. ISIN) in BoardEx to gvkeys in Compustat
# - Initially we wanted to map Company IDs to gvkeys, but we don't have access to the [BoardEx CRSP Compustat Link (Beta)](https://wrds-www.wharton.upenn.edu/pages/get-data/linking-suite-wrds/boardex-crsp-compustat-link/).
# - Instead, we use the [Compustat Global - Fundamentals Annual](https://wrds-www.wharton.upenn.edu/pages/get-data/compustat-capital-iq-standard-poors/compustat/global-daily/fundamentals-annual/) crosswalk to map ISINs to gvkeys.
# - While there's no option to select gvkey as a desired output column, it will automatically be included in the output.

# %%
# Read in ISIN to gvkey crosswalk
isin_gvkey_crosswalk_filepath = Path(parent_dir(parent_dir(os.getcwd())) / Path('output/03_get_firm_and_manager_level_datasets/board_summary_isin_gvkey_crosswalk.csv'))
isin_gvkey_crosswalk = pd.read_csv(isin_gvkey_crosswalk_filepath)
isin_gvkey_crosswalk
# Out:
#         gvkey   fyear    datadate          isin                  conm  \
# 0        1166  1996.0  1996-12-31  NL0000334118  ASM INTERNATIONAL NV
# 1        1166  1997.0  1997-12-31  NL0000334118  ASM INTERNATIONAL NV
# 2        1166  1998.0  1998-12-31  NL0000334118  ASM INTERNATIONAL NV
# 3        1166  1999.0  1999-12-31  NL0000334118  ASM INTERNATIONAL NV
# 4        1166  2000.0  2000-12-31  NL0000334118  ASM INTERNATIONAL NV
# ...       ...     ...         ...           ...                   ...
# 26858  331614  2018.0  2018-12-31  IT0005366767           NEXI S.P.A.
# 26859  331614  2019.0  2019-12-31  IT0005366767           NEXI S.P.A.
# 26860  331614  2020.0  2020-12-31  IT0005366767           NEXI S.P.A.
# 26861  331614  2021.0  2021-12-31  IT0005366767           NEXI S.P.A.
# 26862  331614  2022.0  2022-12-31  IT0005366767           NEXI S.P.A.
#
#             cik
# 0      351483.0
# 1      351483.0
# 2      351483.0
# 3      351483.0
# 4      351483.0
# ...         ...
# 26858       NaN
# 26859       NaN
# 26860       NaN
# 26861       NaN
# 26862       NaN
#
# [26863 rows x 6 columns]

# %%
# Get unique (ISIN, gvkey) combinations
isin_gvkey_crosswalk = isin_gvkey_crosswalk[['gvkey', 'isin']].drop_duplicates()
isin_gvkey_crosswalk
# Out:
#         gvkey          isin
# 0        1166  NL0000334118
# 27       1932  GB0002875804
# 61       2338  GB00BMHTPY25
# 88       5650  JP3788600009
# 124      7471  JP3893600001
# ...       ...           ...
# 26805  325660  DK0060907293
# 26822  325693  FR0013214145
# 26833  326213  AEA006101017
# 26841  327439  FI4000312251
# 26856  331614  IT0005366767
#
# [1083 rows x 2 columns]

# %% [markdown]
# # Merge gvkeys to firm-level dataset on ISINs

# %%
# Merge this back to Board Summary
df_firm_filepath = Path(parent_dir(parent_dir(os.getcwd())) / Path('output/03_get_firm_and_manager_level_datasets/boardex_firm_level_dataset.csv'))
df_firm = pd.read_csv(df_firm_filepath)

# Get first ISIN for each firm
df_firm['isin'] = df_firm['isin'].str.split(',').str[0]

# Merge with gvkeys
df_firm_gvkey = df_firm.merge(isin_gvkey_crosswalk, on='isin', how='left')

# Save df_firm_gvkey
df_firm_gvkey_filepath = Path(parent_dir(parent_dir(os.getcwd())) / Path('output/03_get_firm_and_manager_level_datasets/boardex_firm_level_dataset_gvkey.csv'))
df_firm_gvkey.to_csv(df_firm_gvkey_filepath, index=False)
df_firm_gvkey_filepath = Path(parent_dir(parent_dir(os.getcwd())) / Path('output/03_get_firm_and_manager_level_datasets/boardex_firm_level_dataset_gvkey.csv'))
df_firm_gvkey.to_stata(df_firm_gvkey_filepath, write_index=False, version=117)

df_firm_gvkey
